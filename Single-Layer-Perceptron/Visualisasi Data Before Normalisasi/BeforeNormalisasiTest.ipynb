# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel('D:/Matkul/JARINGAN SYARAF TIRUAN/TUGAS KELOMPOK/Data/Data Testing.xlsx')
df
# Out:
#      Unnamed: 0  PassengerId  Pclass  Sex   Age  SibSp  Parch      Fare  \
# 0             0          892       3    1  34.5      0      0    7.8292
# 1             1          893       3    0  47.0      1      0    7.0000
# 2             2          894       2    1  62.0      0      0    9.6875
# 3             3          895       3    1  27.0      0      0    8.6625
# 4             4          896       3    0  22.0      1      1   12.2875
# ..          ...          ...     ...  ...   ...    ...    ...       ...
# 326         326         1301       3    0   3.0      1      1   13.7750
# 327         327         1303       1    0  37.0      1      0   90.0000
# 328         328         1304       3    0  28.0      0      0    7.7750
# 329         329         1306       1    0  39.0      0      0  108.9000
# 330         330         1307       3    1  38.5      0      0    7.2500
#
#      Embarked
# 0           1
# 1           2
# 2           1
# 3           2
# 4           2
# ...

# %%
plt.figure(figsize=(10, 6))
sns.displot(data=df, x='PassengerId', color='Green')
plt.title('Histogram Data')
plt.xlabel('PassengerId')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Pclass',color='Green')
plt.title('Histogram Data')
plt.xlabel('Pclass')
plt.show()

# %%
Sex_counts = df['Sex'].value_counts()
plt.figure(figsize=(10, 6))
plt.pie(Sex_counts, labels=Sex_counts.index, autopct='%1.1f%%', colors=['Green', 'red'])
plt.title('Histogram Data')
plt.xlabel('Sex')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.displot(data=df, x='Age', kind='kde', color='blue')
plt.title('Histogram Data')
plt.xlabel('Age')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Embarked', color='red')
plt.title('Histogram Data')
plt.xlabel('Embarked')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='SibSp', color='red')
plt.title('Histogram Data')
plt.xlabel('SibSp')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Parch', color='Orange')
plt.title('Histogram Data')
plt.xlabel('Pacrh')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.displot(data=df, x='Fare',kind='kde',color='red')
plt.title('Histogram Data')
plt.xlabel('Fare')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Embarked', color='blue')
plt.title('Histogram Data')
plt.xlabel('Embarked')
plt.show()
