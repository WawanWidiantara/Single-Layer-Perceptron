# %%
dt = pd.read_csv("data/test_data_cl.csv", header=None, names=list(range(12)))

gdt = pd.read_csv("data/test_data_GroundTruth_cl.csv")
dt = dt.head(331)
dt
# Out:
#               0       1              2
# 0    PassengerId  Pclass           Name  \
# 1            892       3          Kelly
# 2            893       3         Wilkes
# 3            894       2          Myles
# 4            895       3           Wirz
# ..           ...     ...            ...
# 326         1299       1        Widener
# 327         1301       3        Peacock
# 328         1303       1        Minahan
# 329         1304       3     Henriksson
# 330         1306       1  Oliva y Ocana
#
#                                           3       4      5      6       7
# 0                                        Sex     Age  SibSp  Parch  Ticket  \
# 1                                  Mr. James    male   34.5      0       0
# 2                   Mrs. James (Ellen Needs)  female     47      1       0
# 3                         Mr. Thomas Francis    male     62      0       0
# 4                                 Mr. Albert    male     27      0       0
# ...
