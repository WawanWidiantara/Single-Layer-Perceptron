# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel('D:/Matkul/JARINGAN SYARAF TIRUAN/TUGAS KELOMPOK/Data/Data Training.xlsx')
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  \
# 0             0            1         0       3    1  22.0      1      0
# 1             1            2         1       1    0  38.0      1      0
# 2             2            3         1       3    0  26.0      0      0
# 3             3            4         1       1    0  35.0      1      0
# 4             4            5         0       3    1  35.0      0      0
# ..          ...          ...       ...     ...  ...   ...    ...    ...
# 707         707          886         0       3    0  39.0      0      5
# 708         708          887         0       2    1  27.0      0      0
# 709         709          888         1       1    0  19.0      0      0
# 710         710          890         1       1    1  26.0      0      0
# 711         711          891         0       3    1  32.0      0      0
#
#         Fare  Embarked
# 0     7.2500         2
# 1    71.2833         0
# 2     7.9250         2
# ...

# %%
survived_labels = ['Not Survived', 'Survived']

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='PassengerId', hue='Survived')
plt.title('Histogram Data')
plt.xlabel('PassengerId')
plt.ylabel('Jumlah')
plt.legend(title='Survived', labels=survived_labels)
plt.show()

# %%
survived_labels = ['Not Survived', 'Survived']

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Pclass', hue='Survived')
plt.title('Histogram Data')
plt.xlabel('Pclass')
plt.ylabel('Jumlah')
plt.legend(title='Survived', labels=survived_labels)
plt.show()

# %%
survived_labels = ['Not Survived', 'Survived']

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Sex', hue='Survived')
plt.title('Histogram Data')
plt.xlabel('Sex')
plt.ylabel('Jumlah')
plt.legend(title='Survived', labels=survived_labels)
plt.show()

# %%
survived_labels = ['Survived', 'Not Survived']
plt.figure(figsize=(10, 6))
sns.displot(data=df, x='Age', kind='kde', hue='Survived')
plt.title('Histogram Data')
plt.legend(title='Survived', labels=survived_labels)
plt.xlabel('Age')
plt.show()

# %%
survived_labels = ['Not Survived', 'Survived']
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='SibSp', hue='Survived')
plt.title('Histogram Data')
plt.legend(title='Survived', labels=survived_labels)
plt.xlabel('SibSp')
plt.ylabel('Jumlah')
plt.show()

# %%
survived_labels = ['Not Survived', 'Survived']
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Parch', hue='Survived')
plt.title('Histogram Data')
plt.legend(title='Survived', labels=survived_labels)
plt.xlabel('Parch')
plt.ylabel('Jumlah')
plt.show()

# %%
survived_labels = ['Survived', 'Not Survived']
plt.figure(figsize=(10, 6))
sns.displot(data=df, x='Fare', kind='kde', hue='Survived')
plt.title('Histogram Data')
plt.legend(title='Survived', labels=survived_labels)
plt.xlabel('Fare')
plt.show()

# %%
survived_labels = ['Not Survived', 'Survived']

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Embarked', hue='Survived')
plt.title('Histogram Data')
plt.legend(title='Survived', labels=survived_labels)
plt.xlabel('Embarked')
plt.ylabel('Jumlah')
plt.show()
